# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import datetime
import scipy.stats as st
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 581

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"
# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{query_url}{city}"
       
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))
    
    # Add 1 to the record count
    record_count += 1
    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather =requests.get(city_url).json()
         # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})
      
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mount pearl
# Processing Record 2 of Set 1 | kasongo
# Processing Record 3 of Set 1 | muang phonsavan
# Processing Record 4 of Set 1 | ust-nera
# Processing Record 5 of Set 1 | bonthe
# Processing Record 6 of Set 1 | edinburgh of the seven seas
# Processing Record 7 of Set 1 | tolanaro
# Processing Record 8 of Set 1 | albany
# Processing Record 9 of Set 1 | devinuwara
# City not found. Skipping...
# Processing Record 10 of Set 1 | port-aux-francais
# Processing Record 11 of Set 1 | iqaluit
# Processing Record 12 of Set 1 | port mathurin
# Processing Record 13 of Set 1 | limon
# Processing Record 14 of Set 1 | mogocha
# Processing Record 15 of Set 1 | karratha
# Processing Record 16 of Set 1 | longyearbyen
# Processing Record 17 of Set 1 | nova vicosa
# Processing Record 18 of Set 1 | waitangi
# Processing Record 19 of Set 1 | stanley
# Processing Record 20 of Set 1 | vingt cinq
# City not found. Skipping...
# Processing Record 21 of Set 1 | baro
# Processing Record 22 of Set 1 | blackmans bay
# Processing Record 23 of Set 1 | berezovyy
# Processing Record 24 of Set 1 | puerto natales
# Processing Record 25 of Set 1 | avarua
# Processing Record 26 of Set 1 | buka
# Processing Record 27 of Set 1 | olonkinbyen
# Processing Record 28 of Set 1 | bubaque
# Processing Record 29 of Set 1 | adamstown
# Processing Record 30 of Set 1 | nuuk
# Processing Record 31 of Set 1 | kirensk
# Processing Record 32 of Set 1 | darreh shahr
# City not found. Skipping...
# Processing Record 33 of Set 1 | mazagao
# Processing Record 34 of Set 1 | ushuaia
# Processing Record 35 of Set 1 | talnakh
# Processing Record 36 of Set 1 | vorgashor
# Processing Record 37 of Set 1 | progreso
# Processing Record 38 of Set 1 | fayetteville
# Processing Record 39 of Set 1 | le port
# Processing Record 40 of Set 1 | west island
# Processing Record 41 of Set 1 | ilulissat
# Processing Record 42 of Set 1 | richards bay
# Processing Record 43 of Set 1 | besisahar
# Processing Record 44 of Set 1 | lautoka
# Processing Record 45 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 46 of Set 1 | hermanus
# Processing Record 47 of Set 1 | invercargill
# Processing Record 48 of Set 1 | gebeit
# Processing Record 49 of Set 1 | iquique
# Processing Record 50 of Set 1 | onega
# Processing Record 0 of Set 2 | chapaev
# Processing Record 1 of Set 2 | el nido
# Processing Record 2 of Set 2 | thompson
# Processing Record 3 of Set 2 | tahe
# Processing Record 4 of Set 2 | punta arenas
# Processing Record 5 of Set 2 | cidreira
# Processing Record 6 of Set 2 | utrik
# Processing Record 7 of Set 2 | holdenville
# Processing Record 8 of Set 2 | ban khlong bang sao thong
# Processing Record 9 of Set 2 | san antonio de pale
# Processing Record 10 of Set 2 | tosontsengel
# Processing Record 11 of Set 2 | illizi
# Processing Record 12 of Set 2 | st. john's
# Processing Record 13 of Set 2 | ulladulla
# Processing Record 14 of Set 2 | shengli
# Processing Record 15 of Set 2 | grytviken
# Processing Record 16 of Set 2 | katsuura
# Processing Record 17 of Set 2 | bethel
# Processing Record 18 of Set 2 | oruro
# Processing Record 19 of Set 2 | zhezqazghan
# Processing Record 20 of Set 2 | carnarvon
# Processing Record 21 of Set 2 | vikhorevka
# Processing Record 22 of Set 2 | khandyga
# Processing Record 23 of Set 2 | ancud
# Processing Record 24 of Set 2 | new norfolk
# Processing Record 25 of Set 2 | margaret river
# Processing Record 26 of Set 2 | ola
# Processing Record 27 of Set 2 | puerto san jose
# Processing Record 28 of Set 2 | aasiaat
# Processing Record 29 of Set 2 | luoyang
# Processing Record 30 of Set 2 | badger
# Processing Record 31 of Set 2 | guerrero negro
# Processing Record 32 of Set 2 | opuwo
# Processing Record 33 of Set 2 | taoudenni
# Processing Record 34 of Set 2 | east london
# Processing Record 35 of Set 2 | pochinok
# Processing Record 36 of Set 2 | lundazi
# Processing Record 37 of Set 2 | dongtai
# Processing Record 38 of Set 2 | kembe
# Processing Record 39 of Set 2 | gargalianoi
# Processing Record 40 of Set 2 | georgetown
# Processing Record 41 of Set 2 | pandan
# Processing Record 42 of Set 2 | hotan
# Processing Record 43 of Set 2 | yellowknife
# Processing Record 44 of Set 2 | muskegon
# Processing Record 45 of Set 2 | port alfred
# Processing Record 46 of Set 2 | bilibino
# Processing Record 47 of Set 2 | hawaiian paradise park
# Processing Record 48 of Set 2 | loei
# Processing Record 49 of Set 2 | constantia
# Processing Record 0 of Set 3 | uturoa
# Processing Record 1 of Set 3 | greymouth
# Processing Record 2 of Set 3 | lihue
# Processing Record 3 of Set 3 | tazovsky
# Processing Record 4 of Set 3 | lerwick
# Processing Record 5 of Set 3 | anaconda
# Processing Record 6 of Set 3 | atafu village
# Processing Record 7 of Set 3 | chibougamau
# Processing Record 8 of Set 3 | novaya ladoga
# Processing Record 9 of Set 3 | isafjordur
# Processing Record 10 of Set 3 | qaqortoq
# Processing Record 11 of Set 3 | sisimiut
# Processing Record 12 of Set 3 | anadyr
# Processing Record 13 of Set 3 | nishinoomote
# Processing Record 14 of Set 3 | afaahiti
# Processing Record 15 of Set 3 | preston
# Processing Record 16 of Set 3 | nova sintra
# Processing Record 17 of Set 3 | college
# Processing Record 18 of Set 3 | eraan
# Processing Record 19 of Set 3 | bredasdorp
# Processing Record 20 of Set 3 | fredericton
# Processing Record 21 of Set 3 | nyrob
# Processing Record 22 of Set 3 | laascaanood
# Processing Record 23 of Set 3 | jabat
# Processing Record 24 of Set 3 | klyuchi
# Processing Record 25 of Set 3 | toga village
# City not found. Skipping...
# Processing Record 26 of Set 3 | ostrov
# Processing Record 27 of Set 3 | colonia
# Processing Record 28 of Set 3 | bella vista
# Processing Record 29 of Set 3 | lompoc
# Processing Record 30 of Set 3 | haiku-pauwela
# Processing Record 31 of Set 3 | tannum sands
# Processing Record 32 of Set 3 | zhigalovo
# Processing Record 33 of Set 3 | port elizabeth
# Processing Record 34 of Set 3 | presidente medici
# Processing Record 35 of Set 3 | chonchi
# Processing Record 36 of Set 3 | kodungallur
# Processing Record 37 of Set 3 | kruisfontein
# Processing Record 38 of Set 3 | gaspe
# Processing Record 39 of Set 3 | wakkanai
# Processing Record 40 of Set 3 | lamarque
# Processing Record 41 of Set 3 | kayenta
# Processing Record 42 of Set 3 | cannonvale
# Processing Record 43 of Set 3 | puerto ayora
# Processing Record 44 of Set 3 | nadbai
# Processing Record 45 of Set 3 | wailua homesteads
# Processing Record 46 of Set 3 | whitehorse
# Processing Record 47 of Set 3 | sola
# Processing Record 48 of Set 3 | edinet
# Processing Record 49 of Set 3 | zouerate
# Processing Record 0 of Set 4 | castillos
# Processing Record 1 of Set 4 | alliance
# Processing Record 2 of Set 4 | new plymouth
# Processing Record 3 of Set 4 | arraial do cabo
# Processing Record 4 of Set 4 | colonia menno
# Processing Record 5 of Set 4 | catalhoyuk
# Processing Record 6 of Set 4 | namtsy
# Processing Record 7 of Set 4 | harstad
# Processing Record 8 of Set 4 | puerto leguizamo
# Processing Record 9 of Set 4 | yangor
# City not found. Skipping...
# Processing Record 10 of Set 4 | udachny
# Processing Record 11 of Set 4 | ribeira grande
# Processing Record 12 of Set 4 | tiksi
# Processing Record 13 of Set 4 | pisco
# Processing Record 14 of Set 4 | champerico
# Processing Record 15 of Set 4 | puerto san carlos
# City not found. Skipping...
# Processing Record 16 of Set 4 | falun
# Processing Record 17 of Set 4 | akureyri
# Processing Record 18 of Set 4 | touros
# Processing Record 19 of Set 4 | usinsk
# Processing Record 20 of Set 4 | taltal
# Processing Record 21 of Set 4 | ust-tsilma
# Processing Record 22 of Set 4 | jamestown
# Processing Record 23 of Set 4 | stephenville
# Processing Record 24 of Set 4 | vredenburg
# City not found. Skipping...
# Processing Record 25 of Set 4 | burela de cabo
# Processing Record 26 of Set 4 | hadibu
# Processing Record 27 of Set 4 | edgewater
# Processing Record 28 of Set 4 | papatowai
# Processing Record 29 of Set 4 | tsiombe
# Processing Record 30 of Set 4 | usevia
# Processing Record 31 of Set 4 | kingsland
# Processing Record 32 of Set 4 | fada
# Processing Record 33 of Set 4 | flying fish cove
# Processing Record 34 of Set 4 | lucapa
# Processing Record 35 of Set 4 | usakos
# Processing Record 36 of Set 4 | salmas
# Processing Record 37 of Set 4 | corod
# Processing Record 38 of Set 4 | kuraymah
# Processing Record 39 of Set 4 | pasargad
# City not found. Skipping...
# Processing Record 40 of Set 4 | malango
# Processing Record 41 of Set 4 | angaur state
# Processing Record 42 of Set 4 | serpa
# Processing Record 43 of Set 4 | mili
# Processing Record 44 of Set 4 | kovylkino
# Processing Record 45 of Set 4 | san andres
# Processing Record 46 of Set 4 | gizo
# Processing Record 47 of Set 4 | minas de marcona
# Processing Record 48 of Set 4 | hithadhoo
# Processing Record 49 of Set 4 | murzuq
# Processing Record 0 of Set 5 | rongelap
# Processing Record 1 of Set 5 | shingu
# Processing Record 2 of Set 5 | merowe
# Processing Record 3 of Set 5 | neustrelitz
# Processing Record 4 of Set 5 | pontianak
# Processing Record 5 of Set 5 | ulricehamn
# Processing Record 6 of Set 5 | faya-largeau
# Processing Record 7 of Set 5 | inarajan village
# Processing Record 8 of Set 5 | taulaga
# Processing Record 9 of Set 5 | broome
# Processing Record 10 of Set 5 | chernyshevskiy
# Processing Record 11 of Set 5 | bardai
# Processing Record 12 of Set 5 | luanda
# Processing Record 13 of Set 5 | yuzhno-kurilsk
# Processing Record 14 of Set 5 | saldanha
# Processing Record 15 of Set 5 | sept-iles
# Processing Record 16 of Set 5 | lemvig
# Processing Record 17 of Set 5 | saldus
# Processing Record 18 of Set 5 | groningen
# Processing Record 19 of Set 5 | takamaka
# City not found. Skipping...
# Processing Record 20 of Set 5 | barra de santo antonio
# Processing Record 21 of Set 5 | carutapera
# Processing Record 22 of Set 5 | jardim do serido
# Processing Record 23 of Set 5 | lata
# Processing Record 24 of Set 5 | kodiak
# Processing Record 25 of Set 5 | hamilton
# Processing Record 26 of Set 5 | la'ie
# Processing Record 27 of Set 5 | moraleja
# Processing Record 28 of Set 5 | kingston
# Processing Record 29 of Set 5 | shetpe
# Processing Record 30 of Set 5 | hobyo
# Processing Record 31 of Set 5 | yinzhu
# Processing Record 32 of Set 5 | huarmey
# Processing Record 33 of Set 5 | vila franca do campo
# Processing Record 34 of Set 5 | ciudad lazaro cardenas
# Processing Record 35 of Set 5 | crane
# Processing Record 36 of Set 5 | beau vallon
# Processing Record 37 of Set 5 | sinabang
# Processing Record 38 of Set 5 | sidi bel abbes
# Processing Record 39 of Set 5 | gueltat zemmour
# City not found. Skipping...
# Processing Record 40 of Set 5 | tamanrasset
# Processing Record 41 of Set 5 | venado
# Processing Record 42 of Set 5 | dryden
# Processing Record 43 of Set 5 | vadso
# Processing Record 44 of Set 5 | callao
# Processing Record 45 of Set 5 | sao tome
# Processing Record 46 of Set 5 | laramie
# Processing Record 47 of Set 5 | formosa
# Processing Record 48 of Set 5 | el matama
# Processing Record 49 of Set 5 | iskateley
# Processing Record 0 of Set 6 | akdepe
# Processing Record 1 of Set 6 | danilovka
# Processing Record 2 of Set 6 | petropavlovsk-kamchatsky
# Processing Record 3 of Set 6 | yunyang
# Processing Record 4 of Set 6 | sao lourenco do sul
# Processing Record 5 of Set 6 | tofol
# Processing Record 6 of Set 6 | muravlenko
# Processing Record 7 of Set 6 | vilyuchinsk
# Processing Record 8 of Set 6 | hami
# Processing Record 9 of Set 6 | pechora
# Processing Record 10 of Set 6 | egilsstadir
# Processing Record 11 of Set 6 | san julian
# Processing Record 12 of Set 6 | korla
# Processing Record 13 of Set 6 | chaykovskiy
# Processing Record 14 of Set 6 | alesund
# Processing Record 15 of Set 6 | darab
# Processing Record 16 of Set 6 | motril
# Processing Record 17 of Set 6 | maputo
# Processing Record 18 of Set 6 | salina
# Processing Record 19 of Set 6 | nar'yan-mar
# Processing Record 20 of Set 6 | ponta delgada
# Processing Record 21 of Set 6 | howrah
# Processing Record 22 of Set 6 | williams lake
# Processing Record 23 of Set 6 | howard springs
# Processing Record 24 of Set 6 | gadzhiyevo
# Processing Record 25 of Set 6 | bairnsdale
# Processing Record 26 of Set 6 | vyazemskiy
# Processing Record 27 of Set 6 | treasure island
# Processing Record 28 of Set 6 | gornopravdinsk
# Processing Record 29 of Set 6 | woolgoolga
# Processing Record 30 of Set 6 | siwa oasis
# Processing Record 31 of Set 6 | babu
# Processing Record 32 of Set 6 | shenjiamen
# Processing Record 33 of Set 6 | kolonia town
# Processing Record 34 of Set 6 | franklin
# Processing Record 35 of Set 6 | stung treng
# Processing Record 36 of Set 6 | belmonte
# Processing Record 37 of Set 6 | keflavik
# Processing Record 38 of Set 6 | ulysses
# Processing Record 39 of Set 6 | pecos
# Processing Record 40 of Set 6 | micheweni
# Processing Record 41 of Set 6 | sokur
# Processing Record 42 of Set 6 | staraya kulatka
# Processing Record 43 of Set 6 | brigantine
# Processing Record 44 of Set 6 | kampong thom
# Processing Record 45 of Set 6 | nouadhibou
# Processing Record 46 of Set 6 | port glaud
# City not found. Skipping...
# Processing Record 47 of Set 6 | puerto gaitan
# Processing Record 48 of Set 6 | kushiro
# Processing Record 49 of Set 6 | chui
# Processing Record 0 of Set 7 | tralee
# Processing Record 1 of Set 7 | namdrik
# Processing Record 2 of Set 7 | ongjin
# Processing Record 3 of Set 7 | prince george
# Processing Record 4 of Set 7 | cabo san lucas
# Processing Record 5 of Set 7 | konarka
# Processing Record 6 of Set 7 | nantucket
# Processing Record 7 of Set 7 | yur'yev-pol'skiy
# Processing Record 8 of Set 7 | sonsorol village
# City not found. Skipping...
# Processing Record 9 of Set 7 | al jawf
# Processing Record 10 of Set 7 | coihueco
# Processing Record 11 of Set 7 | naze
# Processing Record 12 of Set 7 | anqiu
# Processing Record 13 of Set 7 | zonguldak
# Processing Record 14 of Set 7 | port lincoln
# Processing Record 15 of Set 7 | welland
# Processing Record 16 of Set 7 | taksimo
# Processing Record 17 of Set 7 | rajapur
# Processing Record 18 of Set 7 | kargil
# Processing Record 19 of Set 7 | billings
# Processing Record 20 of Set 7 | deqen
# Processing Record 21 of Set 7 | bluefields
# Processing Record 22 of Set 7 | cacu
# Processing Record 23 of Set 7 | bac lieu
# Processing Record 24 of Set 7 | portage la prairie
# Processing Record 25 of Set 7 | namibe
# Processing Record 26 of Set 7 | mukalla
# Processing Record 27 of Set 7 | kenai
# Processing Record 28 of Set 7 | dudinka
# Processing Record 29 of Set 7 | qapqal
# City not found. Skipping...
# Processing Record 30 of Set 7 | amble
# Processing Record 31 of Set 7 | grand falls-windsor
# Processing Record 32 of Set 7 | sao vicente
# Processing Record 33 of Set 7 | mammoth lakes
# Processing Record 34 of Set 7 | mount gambier
# Processing Record 35 of Set 7 | kapa'a
# Processing Record 36 of Set 7 | pudasjarvi
# Processing Record 37 of Set 7 | enewetak
# Processing Record 38 of Set 7 | ta`u
# Processing Record 39 of Set 7 | okhotsk
# Processing Record 40 of Set 7 | stawell
# Processing Record 41 of Set 7 | waddan
# Processing Record 42 of Set 7 | lebu
# Processing Record 43 of Set 7 | jayapura
# Processing Record 44 of Set 7 | forster
# Processing Record 45 of Set 7 | lamballe
# Processing Record 46 of Set 7 | fuvahmulah
# City not found. Skipping...
# Processing Record 47 of Set 7 | elliot lake
# Processing Record 48 of Set 7 | port augusta
# Processing Record 49 of Set 7 | tarija
# Processing Record 0 of Set 8 | qinzhou
# Processing Record 1 of Set 8 | 'ohonua
# City not found. Skipping...
# Processing Record 2 of Set 8 | beyneu
# Processing Record 3 of Set 8 | ashland
# Processing Record 4 of Set 8 | weining
# Processing Record 5 of Set 8 | smirnykh
# Processing Record 6 of Set 8 | atamaria
# City not found. Skipping...
# Processing Record 7 of Set 8 | alexandria
# Processing Record 8 of Set 8 | kharp
# Processing Record 9 of Set 8 | farafangana
# Processing Record 10 of Set 8 | jiagedaqi
# Processing Record 11 of Set 8 | necochea
# Processing Record 12 of Set 8 | razam
# Processing Record 13 of Set 8 | martapura
# Processing Record 14 of Set 8 | bathsheba
# Processing Record 15 of Set 8 | trincomalee
# Processing Record 16 of Set 8 | mercedes
# Processing Record 17 of Set 8 | aqadyr
# Processing Record 18 of Set 8 | victorica
# Processing Record 19 of Set 8 | grand-bassam
# Processing Record 20 of Set 8 | ebon
# Processing Record 21 of Set 8 | pagar alam
# Processing Record 22 of Set 8 | nuku'alofa
# Processing Record 23 of Set 8 | tindouf
# Processing Record 24 of Set 8 | miranda
# Processing Record 25 of Set 8 | gouyave
# Processing Record 26 of Set 8 | tshabong
# Processing Record 27 of Set 8 | nemuro
# Processing Record 28 of Set 8 | monett
# Processing Record 29 of Set 8 | zhaotong
# Processing Record 30 of Set 8 | salekhard
# Processing Record 31 of Set 8 | indramayu
# Processing Record 32 of Set 8 | richmond
# Processing Record 33 of Set 8 | siddipet
# Processing Record 34 of Set 8 | kandyagash
# Processing Record 35 of Set 8 | mata-utu
# Processing Record 36 of Set 8 | pangkalanbuun
# Processing Record 37 of Set 8 | trevelin
# Processing Record 38 of Set 8 | saint-louis
# Processing Record 39 of Set 8 | diu
# Processing Record 40 of Set 8 | palmer
# Processing Record 41 of Set 8 | qamdo
# Processing Record 42 of Set 8 | susuman
# Processing Record 43 of Set 8 | tionk essil
# Processing Record 44 of Set 8 | kununurra
# Processing Record 45 of Set 8 | nuriootpa
# Processing Record 46 of Set 8 | brixham
# Processing Record 47 of Set 8 | inhambane
# Processing Record 48 of Set 8 | moapa valley
# Processing Record 49 of Set 8 | sambava
# Processing Record 0 of Set 9 | mikhaylovskoye
# Processing Record 1 of Set 9 | ndago
# Processing Record 2 of Set 9 | rokycany
# Processing Record 3 of Set 9 | fannuj
# City not found. Skipping...
# Processing Record 4 of Set 9 | west end
# Processing Record 5 of Set 9 | villa gesell
# Processing Record 6 of Set 9 | spring creek
# Processing Record 7 of Set 9 | wynyard
# Processing Record 8 of Set 9 | barcelos
# Processing Record 9 of Set 9 | dunedin
# Processing Record 10 of Set 9 | cargados carajos
# City not found. Skipping...
# Processing Record 11 of Set 9 | ocean pointe
# City not found. Skipping...
# Processing Record 12 of Set 9 | kerikeri
# Processing Record 13 of Set 9 | saipan
# Processing Record 14 of Set 9 | novoshakhtinskiy
# Processing Record 15 of Set 9 | priladozhskiy
# Processing Record 16 of Set 9 | mariental
# Processing Record 17 of Set 9 | mount isa
# Processing Record 18 of Set 9 | san pedro
# Processing Record 19 of Set 9 | sandnessjoen
# Processing Record 20 of Set 9 | griffith
# Processing Record 21 of Set 9 | great falls
# Processing Record 22 of Set 9 | atbara
# Processing Record 23 of Set 9 | metlili chaamba
# Processing Record 24 of Set 9 | coquimbo
# Processing Record 25 of Set 9 | rundu
# Processing Record 26 of Set 9 | malpica
# Processing Record 27 of Set 9 | molochnoye
# Processing Record 28 of Set 9 | temple
# Processing Record 29 of Set 9 | bargaal
# Processing Record 30 of Set 9 | kansk
# Processing Record 31 of Set 9 | san luis
# Processing Record 32 of Set 9 | arboga
# Processing Record 33 of Set 9 | acajutla
# Processing Record 34 of Set 9 | ivins
# Processing Record 35 of Set 9 | rio grande
# Processing Record 36 of Set 9 | sarh
# Processing Record 37 of Set 9 | aral
# Processing Record 38 of Set 9 | cumnock
# Processing Record 39 of Set 9 | kiunga
# Processing Record 40 of Set 9 | nanao
# Processing Record 41 of Set 9 | neryungri
# Processing Record 42 of Set 9 | palikir - national government center
# Processing Record 43 of Set 9 | kingscliff
# Processing Record 44 of Set 9 | kulhudhuffushi
# Processing Record 45 of Set 9 | al hazm
# Processing Record 46 of Set 9 | springfield
# Processing Record 47 of Set 9 | kayangel
# Processing Record 48 of Set 9 | remire-montjoly
# Processing Record 49 of Set 9 | blenheim
# Processing Record 0 of Set 10 | ares
# Processing Record 1 of Set 10 | suwalki
# Processing Record 2 of Set 10 | hovd
# Processing Record 3 of Set 10 | kuanda
# Processing Record 4 of Set 10 | sitka
# Processing Record 5 of Set 10 | belyy yar
# Processing Record 6 of Set 10 | sur
# Processing Record 7 of Set 10 | sarangani
# Processing Record 8 of Set 10 | portland
# Processing Record 9 of Set 10 | dakhla
# Processing Record 10 of Set 10 | copala
# Processing Record 11 of Set 10 | ishigaki
# Processing Record 12 of Set 10 | napier
# Processing Record 13 of Set 10 | kataragama
# City not found. Skipping...
# Processing Record 14 of Set 10 | brisas de zicatela
# Processing Record 15 of Set 10 | kapuskasing
# Processing Record 16 of Set 10 | codrington
# Processing Record 17 of Set 10 | zhangye
# Processing Record 18 of Set 10 | dourbali
# Processing Record 19 of Set 10 | pervomayskoye
# Processing Record 20 of Set 10 | jieshi
# Processing Record 21 of Set 10 | porto velho
# Processing Record 22 of Set 10 | yelizovo
# Processing Record 23 of Set 10 | beloyarskiy
# Processing Record 24 of Set 10 | fort bragg
# Processing Record 25 of Set 10 | buala
# Processing Record 26 of Set 10 | campo verde
# Processing Record 27 of Set 10 | manokwari
# Processing Record 28 of Set 10 | nkurenkuru
# City not found. Skipping...
# Processing Record 29 of Set 10 | bayganin
# Processing Record 30 of Set 10 | turtas
# Processing Record 31 of Set 10 | lamu
# Processing Record 32 of Set 10 | sena madureira
# Processing Record 33 of Set 10 | brooks
# Processing Record 34 of Set 10 | kwali
# Processing Record 35 of Set 10 | cheboksary
# Processing Record 36 of Set 10 | bikenibeu village
# Processing Record 37 of Set 10 | erdenet
# Processing Record 38 of Set 10 | sumbawa besar
# Processing Record 39 of Set 10 | kabalo
# Processing Record 40 of Set 10 | nyurba
# Processing Record 41 of Set 10 | la ronge
# Processing Record 42 of Set 10 | fale old settlement
# Processing Record 43 of Set 10 | grenaa
# Processing Record 44 of Set 10 | castelli
# Processing Record 45 of Set 10 | dashiqiao
# Processing Record 46 of Set 10 | puerto princesa
# Processing Record 47 of Set 10 | hobbs
# Processing Record 48 of Set 10 | arrifes
# Processing Record 49 of Set 10 | najran
# Processing Record 0 of Set 11 | bor
# Processing Record 1 of Set 11 | holualoa
# Processing Record 2 of Set 11 | carlinville
# Processing Record 3 of Set 11 | xinguara
# City not found. Skipping...
# Processing Record 4 of Set 11 | alatyr'
# Processing Record 5 of Set 11 | luau
# Processing Record 6 of Set 11 | yangjiang
# Processing Record 7 of Set 11 | saint-francois
# Processing Record 8 of Set 11 | harper
# Processing Record 9 of Set 11 | marco island
# Processing Record 10 of Set 11 | kambove
# Processing Record 11 of Set 11 | plastun
# Processing Record 12 of Set 11 | inverloch
# Processing Record 13 of Set 11 | happy valley-goose bay
# Processing Record 14 of Set 11 | rio preto da eva
# Processing Record 15 of Set 11 | aban
# Processing Record 16 of Set 11 | tazacorte
# Processing Record 17 of Set 11 | polyarnyy
# Processing Record 18 of Set 11 | zyryanskoye
# Processing Record 19 of Set 11 | margate
# Processing Record 20 of Set 11 | pauini
# Processing Record 21 of Set 11 | globe
# City not found. Skipping...
# Processing Record 22 of Set 11 | kilju
# Processing Record 23 of Set 11 | kokpekty
# Processing Record 24 of Set 11 | nikel
# Processing Record 25 of Set 11 | dila
# Processing Record 26 of Set 11 | tranovaho
# City not found. Skipping...
# Processing Record 27 of Set 11 | igarka
# Processing Record 28 of Set 11 | mkushi
# Processing Record 29 of Set 11 | trairi
# Processing Record 30 of Set 11 | leirvik
# Processing Record 31 of Set 11 | castanos
# Processing Record 32 of Set 11 | the pas
# Processing Record 33 of Set 11 | hafar al-batin
# Processing Record 34 of Set 11 | pacific grove
# Processing Record 35 of Set 11 | brookings
# Processing Record 36 of Set 11 | bayan nur
# City not found. Skipping...
# Processing Record 37 of Set 11 | misratah
# Processing Record 38 of Set 11 | caucete
# Processing Record 39 of Set 11 | tadine
# Processing Record 40 of Set 11 | hayma'
# City not found. Skipping...
# Processing Record 41 of Set 11 | hegang
# Processing Record 42 of Set 11 | alofi
# Processing Record 43 of Set 11 | beaufort west
# Processing Record 44 of Set 11 | wellington
# Processing Record 45 of Set 11 | fuller heights
# Processing Record 46 of Set 11 | aykhal
# Processing Record 47 of Set 11 | hilo
# Processing Record 48 of Set 11 | grand-bourg
# Processing Record 49 of Set 11 | papao
# Processing Record 0 of Set 12 | mandalgovi
# Processing Record 1 of Set 12 | safford
# Processing Record 2 of Set 12 | borlange
# City not found. Skipping...
# Processing Record 3 of Set 12 | shambu
# Processing Record 4 of Set 12 | yung shue wan
# Processing Record 5 of Set 12 | cody
# Processing Record 6 of Set 12 | arkhara
# Processing Record 7 of Set 12 | yangambi
# Processing Record 8 of Set 12 | rabaul
# Processing Record 9 of Set 12 | miquelon
# Processing Record 10 of Set 12 | motueka
# Processing Record 11 of Set 12 | edeia
# Processing Record 12 of Set 12 | penhalonga
# Processing Record 13 of Set 12 | bestobe
# Processing Record 14 of Set 12 | lorengau
# Processing Record 15 of Set 12 | koprubasi
# Processing Record 16 of Set 12 | chajul
# Processing Record 17 of Set 12 | lethem
# Processing Record 18 of Set 12 | joshimath
# Processing Record 19 of Set 12 | campo largo
# Processing Record 20 of Set 12 | gamba
# Processing Record 21 of Set 12 | kavaratti
# Processing Record 22 of Set 12 | oteapan
# Processing Record 23 of Set 12 | usogorsk
# Processing Record 24 of Set 12 | porto torres
# Processing Record 25 of Set 12 | nadym
# Processing Record 26 of Set 12 | port-vila
# Processing Record 27 of Set 12 | pasuquin
# Processing Record 28 of Set 12 | veraval
# Processing Record 29 of Set 12 | lesosibirsk
# Processing Record 30 of Set 12 | sanming
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
# Show Record Count
city_data_df.count()
# Out:
# City          553
# Lat           553
# Lng           553
# Max Temp      553
# Humidity      553
# Cloudiness    553
# Wind Speed    553
# Country       553
# Date          553
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      mount pearl  47.5166  -52.7813     11.36        66          75
# 1          kasongo  -4.4500   26.6667     27.23        65          71
# 2  muang phonsavan  19.4500  103.2167     17.76        98          20
# 3         ust-nera  64.5667  143.2000      1.21        88         100
# 4           bonthe   7.5264  -12.5050     31.02        67          97
#
#    Wind Speed Country        Date
# 0        6.17      CA  1715269980
# 1        1.39      CD  1715269980
# 2        1.14      LA  1715269980
# 3        2.54      RU  1715269981
# 4        5.15      SL  1715269981

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                     City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0            mount pearl  47.5166  -52.7813     11.36        66          75
# 1                kasongo  -4.4500   26.6667     27.23        65          71
# 2        muang phonsavan  19.4500  103.2167     17.76        98          20
# 3               ust-nera  64.5667  143.2000      1.21        88         100
# 4                 bonthe   7.5264  -12.5050     31.02        67          97
#
#          Wind Speed Country        Date
# City_ID
# 0              6.17      CA  1715269980
# 1              1.39      CD  1715269980
# 2              1.14      LA  1715269980
# 3              2.54      RU  1715269981
# 4              5.15      SL  1715269981

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], marker="o")

# Incorporate the other graph properties
plt.title(F"City Latitude vs max Temprature ({datetime.date.today()})")
plt.ylabel("Temperature (C)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"],city_data_df["Humidity"],marker="o")

# Incorporate the other graph properties
plt.title(f"City Latitude vs Humidity ({datetime.date.today()})")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)
           
# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"],city_data_df["Cloudiness"],marker="o")

# Incorporate the other graph properties
plt.title(f"City Latitude vs Cloudiness ({datetime.date.today()})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"],city_data_df["Wind Speed"],marker="o")

# Incorporate the other graph properties
plt.title(f"City Latitude vas Wind Speed ({datetime.date.today()}) ")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def perform_regression_analysis(data, x, y,hemisphere,xlabel,ylabel):
    x_values=data[x]
    y_values=data[y]
    print(f"The correlation coefficient between {x} and {y} of {hemisphere} is: {round(st.pearsonr(x_values,y_values)[0],2)}")
    
    #linear regression model
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,(x_values.min()+10,y_values.min()+10),fontsize=15,color="red")
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    print(f" The r-squared is: {rvalue**2}")
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df=city_data_df.loc[city_data_df["Lat"]>=0,:]

# Display sample data
northern_hemi_df.head()
# Out:
#                     City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0            mount pearl  47.5166  -52.7813     11.36        66          75
# 2        muang phonsavan  19.4500  103.2167     17.76        98          20
# 3               ust-nera  64.5667  143.2000      1.21        88         100
# 4                 bonthe   7.5264  -12.5050     31.02        67          97
# 7                 albany  42.6001  -73.9662     14.97        64         100
#
#          Wind Speed Country        Date
# City_ID
# 0              6.17      CA  1715269980
# 2              1.14      LA  1715269980
# 3              2.54      RU  1715269981
# 4              5.15      SL  1715269981
# 7              0.89      US  1715269626

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df=city_data_df.loc[city_data_df["Lat"]<0,:]

# Display sample data
southern_hemi_df.head()
# Out:
#                                 City      Lat      Lng  Max Temp  Humidity  \
# City_ID
# 1                            kasongo  -4.4500  26.6667     27.23        65
# 5        edinburgh of the seven seas -37.0676 -12.3116     12.97        58
# 6                           tolanaro -25.0319  46.9987     24.04        83
# 8                  port-aux-francais -49.3500  70.2167      5.25        82
# 10                     port mathurin -19.6833  63.4167     25.57        75
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 1                71        1.39      CD  1715269980
# 5                36        8.39      SH  1715269981
# 6                20        8.23      MG  1715269981
# 8                52       10.84      TF  1715269981
# 10              100       10.73      MU  1715269982

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
perform_regression_analysis(northern_hemi_df,"Lat","Max Temp","Northern Hemisphere","Latitude","Max Temptature (C)")
# Out:
# The correlation coefficient between Lat and Max Temp of Northern Hemisphere is: -0.84
#  The r-squared is: 0.7010995500854134

# %%
# Linear regression on Southern Hemisphere
perform_regression_analysis(southern_hemi_df,"Lat","Max Temp","Southern Hemisphere","Latitude","Max Temptature (C)")
# Out:
# The correlation coefficient between Lat and Max Temp of Southern Hemisphere is: 0.82
#  The r-squared is: 0.671917231183948

# %%
#Discussion about the linear relationship:
#YOUR RESPONSE HERE
print(f"The correlation coefficient (r) that measures the linear correlation between two variables and the direction of the relationship.")
print(f"This value lies between -1 to +1") 
print(f"Value -1 means strong negative relationship between the two variables and +1 is strong postive and 0 is no relationship") 
print(f"Negative relationship means that when independent variable increases then the value of the dependent variable decreases.")
print(f"Positive  relationship means that when independent variable increases then the value of the dependent variable also decreases.")
print(f"r-squared simply measured fraction of the dependency of the dependent variable on the independent variable.")
print(f"If the dependent variable is highly dependent on all of its independent variables, the value will be close to 1.")
print()
print(f"###### Explanation for Northern Hemisphere maximum tempratue change according to the latitude #######")
print()
print(f"The correlation coefficient between Lat and Max Temp of Northern Hemisphere is: -0.86")
print(f"This mean there is a strong negative realtionship between Northern Hemisphere latitude and the maximum tempratue") 
print(f"Maximum tempratue decreases when the latitude figue increase")
print(f"The r-squared is: 0.744 and this means there is a chance of 74% of changing the max temperature by the changing the latitude of the Northern Hemisphere")
print()
print(f"###### Explanation for Southern Hemisphere maximum tempratue change according to the latitude #######")
print()
print(f"The correlation coefficient between Lat and Max Temp of Southern Hemisphere is: 0.74")
print(f"This mean there is a moderate positive realtionship between Southern Hemisphere latitude and the maximum tempratue")
print(f"Maximum tempratue increases when the latitude figue increase")
print(f"The r-squared is: 0.553 and this means there is a chance of 55% of changing the max temperature by the changing the latitude of the Southern Hemisphere")
# Out:
# The correlation coefficient (r) that measures the linear correlation between two variables and the direction of the relationship.
# This value lies between -1 to +1
# Value -1 means strong negative relationship between the two variables and +1 is strong postive and 0 is no relationship
# Negative relationship means that when independent variable increases then the value of the dependent variable decreases.
# Positive  relationship means that when independent variable increases then the value of the dependent variable also decreases.
# r-squared simply measured fraction of the dependency of the dependent variable on the independent variable.
# If the dependent variable is highly dependent on all of its independent variables, the value will be close to 1.
#
# ###### Explanation for Northern Hemisphere maximum tempratue change according to the latitude #######
#
# The correlation coefficient between Lat and Max Temp of Northern Hemisphere is: -0.86
# This mean there is a strong negative realtionship between Northern Hemisphere latitude and the maximum tempratue
# Maximum tempratue decreases when the latitude figue increase
# The r-squared is: 0.744 and this means there is a chance of 74% of changing the max temperature by the changing the latitude of the Northern Hemisphere
#
# ###### Explanation for Southern Hemisphere maximum tempratue change according to the latitude #######
#
# The correlation coefficient between Lat and Max Temp of Southern Hemisphere is: 0.74
# This mean there is a moderate positive realtionship between Southern Hemisphere latitude and the maximum tempratue
# Maximum tempratue increases when the latitude figue increase
# The r-squared is: 0.553 and this means there is a chance of 55% of changing the max temperature by the changing the latitude of the Southern Hemisphere

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
perform_regression_analysis(northern_hemi_df,"Lat","Humidity","Northern Hemisphere","Latitude","Humidity")
# Out:
# The correlation coefficient between Lat and Humidity of Northern Hemisphere is: 0.15
#  The r-squared is: 0.022664707924309736

# %%
# Southern Hemisphere
perform_regression_analysis(southern_hemi_df,"Lat","Humidity","Southern Hemisphere","Latitude","Humidity")
# Out:
# The correlation coefficient between Lat and Humidity of Southern Hemisphere is: 0.01
#  The r-squared is: 3.646577493195441e-05

# %%
#**Discussion about the linear relationship:** YOUR RESPONSE HERE
print(f"###### Explanation for Northern Hemisphere Humidity change according to the latitude #######")
print()
print(f"The correlation coefficient between Lat and Humidity of Northern Hemisphere is: 0.1")
print(f"This mean there is a weak (or no relationship) positive realtionship between Northern Hemisphere latitude and the Humidity") 
print(f"The r-squared is: 0.0093 and this means there is a rare chance of 0.9% of changing the Humidity by the changing the latitude of the Northern Hemisphere")
print()
print(f"###### Explanation for Southern Hemisphere Humidity change according to the latitude #######")
print()
print(f"The correlation coefficient between Lat and Humidity of Southern Hemisphere is: 0.24")
print(f"This mean there is a weak positive realtionship between Southern Hemisphere latitude and the Humidity")
print(f"Humidity might increases when the latitude figue increase")
print(f"The r-squared is:  0.0558 and this means there is a chance of 5% of changing the Humidity by the changing the latitude of the Southern Hemisphere")
# Out:
# ###### Explanation for Northern Hemisphere Humidity change according to the latitude #######
#
# The correlation coefficient between Lat and Humidity of Northern Hemisphere is: 0.1
# This mean there is a weak (or no relationship) positive realtionship between Northern Hemisphere latitude and the Humidity
# The r-squared is: 0.0093 and this means there is a rare chance of 0.9% of changing the Humidity by the changing the latitude of the Northern Hemisphere
#
# ###### Explanation for Southern Hemisphere Humidity change according to the latitude #######
#
# The correlation coefficient between Lat and Humidity of Southern Hemisphere is: 0.24
# This mean there is a weak positive realtionship between Southern Hemisphere latitude and the Humidity
# Humidity might increases when the latitude figue increase
# The r-squared is:  0.0558 and this means there is a chance of 5% of changing the Humidity by the changing the latitude of the Southern Hemisphere

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
perform_regression_analysis(northern_hemi_df,"Lat","Cloudiness","Northern Hemisphere","Latitude","Cloudiness(%)")

# %%
# Southern Hemisphere
perform_regression_analysis(southern_hemi_df,"Lat","Cloudiness","Southern Hemisphere","Latitude","Cloudiness(%)")

# %%
#**Discussion about the linear relationship:** YOUR RESPONSE HERE
print(f"###### Explanation for Northern Hemisphere Cloudiness change according to the latitude #######")
print()
print(f"The correlation coefficient between Lat and Cloudiness of Northern Hemisphere is: 0.05")
print(f"This mean there is a weak (or no relationship) positive realtionship between Northern Hemisphere latitude and the Cloudiness") 
print(f"The r-squared is: 0.0029 and this means there is a rare chance of 0.2% of changing the Cloudiness by the changing the latitude of the Northern Hemisphere")
print()
print(f"###### Explanation for Southern Hemisphere Cloudiness change according to the latitude #######")
print()
print(f"The correlation coefficient between Lat and Cloudiness of Southern Hemisphere is: 0.24")
print(f"This mean there is a weak positive realtionship between Southern Hemisphere latitude and the Cloudiness")
print(f"Cloudiness might increases when the latitude figue increase")
print(f"The r-squared is:  0.0553 and this means there is a chance of 5% of changing the Cloudiness by the changing the latitude of the Southern Hemisphere")
# Out:
# ###### Explanation for Northern Hemisphere Cloudiness change according to the latitude #######
#
# The correlation coefficient between Lat and Cloudiness of Northern Hemisphere is: 0.05
# This mean there is a weak (or no relationship) positive realtionship between Northern Hemisphere latitude and the Cloudiness
# The r-squared is: 0.0029 and this means there is a rare chance of 0.2% of changing the Cloudiness by the changing the latitude of the Northern Hemisphere
#
# ###### Explanation for Southern Hemisphere Cloudiness change according to the latitude #######
#
# The correlation coefficient between Lat and Cloudiness of Southern Hemisphere is: 0.24
# This mean there is a weak positive realtionship between Southern Hemisphere latitude and the Cloudiness
# Cloudiness might increases when the latitude figue increase
# The r-squared is:  0.0553 and this means there is a chance of 5% of changing the Cloudiness by the changing the latitude of the Southern Hemisphere

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
perform_regression_analysis(northern_hemi_df,"Lat","Wind Speed","Northern Hemisphere","Latitude","Wind Speed(m/s)")

# %%
# Southern Hemisphere
perform_regression_analysis(southern_hemi_df,"Lat","Wind Speed","Southern Hemisphere","Latitude","Wind Speed(m/s)")

# %%
#**Discussion about the linear relationship:** YOUR RESPONSE HERE
print(f"###### Explanation for Northern Hemisphere Wind Speed change according to the latitude #######")
print()
print(f"The correlation coefficient between Lat and Wind Speed of Northern Hemisphere is: 0.16")
print(f"This mean there is a weak (or no relationship) positive realtionship between Northern Hemisphere latitude and the Wind Speed") 
print(f"The r-squared is: 0.0264 and this means there is a rare chance of 2% of changing the Wind Speed by the changing the latitude of the Northern Hemisphere")
print()
print(f"###### Explanation for Southern Hemisphere Wind Speed change according to the latitude #######")
print()
print(f"The correlation coefficient between Lat and Wind Speed of Southern Hemisphere is: -0.16")
print(f"This mean there is a weak negative realtionship between Southern Hemisphere latitude and the Wind Speed")
print(f"Wind Speed might decreases when the latitude figue increase")
print(f"The r-squared is: 0.0254 and this means there is a rare chance of 5% of changing the Wind Speed by the changing the latitude of the Southern Hemisphere")
# Out:
# ###### Explanation for Northern Hemisphere Wind Speed change according to the latitude #######
#
# The correlation coefficient between Lat and Wind Speed of Northern Hemisphere is: 0.16
# This mean there is a weak (or no relationship) positive realtionship between Northern Hemisphere latitude and the Wind Speed
# The r-squared is: 0.0264 and this means there is a rare chance of 2% of changing the Wind Speed by the changing the latitude of the Northern Hemisphere
#
# ###### Explanation for Southern Hemisphere Wind Speed change according to the latitude #######
#
# The correlation coefficient between Lat and Wind Speed of Southern Hemisphere is: -0.16
# This mean there is a weak negative realtionship between Southern Hemisphere latitude and the Wind Speed
# Wind Speed might decreases when the latitude figue increase
# The r-squared is: 0.0254 and this means there is a rare chance of 5% of changing the Wind Speed by the changing the latitude of the Southern Hemisphere
